# %% [markdown]
# <a href="https://colab.research.google.com/github/shyookml/fdl/blob/Chap.4/mnist_allinone_wgpu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.datasets.mnist import load_data
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 데이터 불러오기
(x_train_org,y_train_org),(x_test,y_test)=load_data(path='mnist.npz')

# 트레인 데이터를 진짜 train 할 것과 검증할 테스느 데이터로 나누기
x_train,x_val,y_train,y_val=train_test_split(x_train_org,y_train_org,test_size=0.3,random_state=777)

num_x_train=x_train.shape[0]
num_x_val=x_val.shape[0]
num_x_test=x_test.shape[0]

# 1차원 데이터로 전처리
x_train=(x_train.reshape((num_x_train,28*28)))/255
x_val=(x_val.reshape((num_x_val,28*28)))/255
x_test=(x_test.reshape((num_x_test,28*28)))/255

# categorize 위한 train data 변환
# 주의: 변수 이름 바꿨음!!!
y_train_categ=to_categorical(y_train)
y_val_categ=to_categorical(y_val)
y_test_categ=to_categorical(y_test)

# get gup_device
gpu_device_name = tf.test.gpu_device_name()

with tf.device(gpu_device_name):
  # 모델 만들기: 3층 DNN
  model=Sequential()

  model.add(Dense(64,activation='relu', input_shape=(784,)))
  model.add(Dense(32,activation='relu'))
  model.add(Dense(10,activation='softmax'))

  # 모델 묶고
  model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['acc'])
  # 학습
  history=model.fit(x_train,y_train_categ,epochs=30,batch_size=128,validation_data=(x_val,y_val_categ))

  model.evaluate(x_test,y_test_categ)

  # 학습된 모델을 가지고 test 데이터의 값 예측 테스트
  import numpy as np

  results=model.predict(x_test)

print(results.shape)
np.set_printoptions(precision=7)
print(f'각 클래스에 속할 확률\n{results[0]}')
print(f"estimation:{np.argmax(results[0])}")
print(f"정답:{y_test[0]}")
# Out:
# Epoch 1/30
# 329/329 [==============================] - 2s 4ms/step - loss: 0.4776 - acc: 0.8654 - val_loss: 0.2381 - val_acc: 0.9330
# Epoch 2/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1995 - acc: 0.9430 - val_loss: 0.1995 - val_acc: 0.9401
# Epoch 3/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1511 - acc: 0.9563 - val_loss: 0.1497 - val_acc: 0.9578
# Epoch 4/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1202 - acc: 0.9650 - val_loss: 0.1328 - val_acc: 0.9617
# Epoch 5/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0988 - acc: 0.9713 - val_loss: 0.1290 - val_acc: 0.9643
# Epoch 6/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0846 - acc: 0.9751 - val_loss: 0.1229 - val_acc: 0.9644
# Epoch 7/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0724 - acc: 0.9787 - val_loss: 0.1125 - val_acc: 0.9670
# Epoch 8/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0637 - acc: 0.9806 - val_loss: 0.1154 - val_acc: 0.9659
# Epoch 9/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0559 - acc: 0.9830 - val_loss: 0.1075 - val_acc: 0.9696
# Epoch 10/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0491 - acc: 0.9853 - val_loss: 0.1074 - val_acc: 0.9685
# Epoch 11/30
# 329/329 [==============================] - 2s 5ms/step - loss: 0.0421 - acc: 0.9876 - val_loss: 0.1088 - val_acc: 0.9690
# Epoch 12/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0368 - acc: 0.9890 - val_loss: 0.1066 - val_acc: 0.9701
# Epoch 13/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0321 - acc: 0.9910 - val_loss: 0.1058 - val_acc: 0.9691
# Epoch 14/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0287 - acc: 0.9918 - val_loss: 0.1055 - val_acc: 0.9706
# Epoch 15/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0248 - acc: 0.9930 - val_loss: 0.1078 - val_acc: 0.9704
# Epoch 16/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0205 - acc: 0.9943 - val_loss: 0.1120 - val_acc: 0.9706
# Epoch 17/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0181 - acc: 0.9950 - val_loss: 0.1230 - val_acc: 0.9682
# Epoch 18/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0180 - acc: 0.9953 - val_loss: 0.1279 - val_acc: 0.9674
# Epoch 19/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0152 - acc: 0.9959 - val_loss: 0.1280 - val_acc: 0.9682
# Epoch 20/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0134 - acc: 0.9966 - val_loss: 0.1263 - val_acc: 0.9704
# Epoch 21/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0111 - acc: 0.9973 - val_loss: 0.1192 - val_acc: 0.9721
# Epoch 22/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0081 - acc: 0.9982 - val_loss: 0.1243 - val_acc: 0.9723
# Epoch 23/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0094 - acc: 0.9975 - val_loss: 0.1287 - val_acc: 0.9702
# Epoch 24/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0119 - acc: 0.9966 - val_loss: 0.1379 - val_acc: 0.9704
# Epoch 25/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0162 - acc: 0.9946 - val_loss: 0.1365 - val_acc: 0.9702
# Epoch 26/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0054 - acc: 0.9990 - val_loss: 0.1381 - val_acc: 0.9716
# Epoch 27/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0050 - acc: 0.9989 - val_loss: 0.1361 - val_acc: 0.9707
# Epoch 28/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0049 - acc: 0.9992 - val_loss: 0.1359 - val_acc: 0.9715
# Epoch 29/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0027 - acc: 0.9997 - val_loss: 0.1386 - val_acc: 0.9718
# Epoch 30/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0024 - acc: 0.9997 - val_loss: 0.1470 - val_acc: 0.9710
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1408 - acc: 0.9724
# (10000, 10)
# 각 클래스에 속할 확률
# [9.7140908e-17 2.4824251e-13 1.1423926e-12 7.3339010e-08 5.8353812e-21
#  2.6592621e-14 1.1295777e-25 9.9999988e-01 5.0816404e-13 1.1642468e-12]
# estimation:7
# 정답:7
